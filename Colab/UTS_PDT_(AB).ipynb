# %% [markdown]
# <a href="https://colab.research.google.com/github/TheresiaTriOktavia/PDT/blob/main/Colab/UTS_PDT_(AB).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kelompok :
#
# Anggota :
# - Annisa Citra Pratiwi (2217051008)
# - Atikah Oktaria (2217051035)
# - Nazwa Sophia Nadine Effendi (2217051049)
# - Theresia Tri Oktavia I (2217051111)

# %% [markdown]
# # No 1

# %% [markdown]
# Data .csv

# %%
import pandas as pd
import numpy as np

# Load Data .csv
url = "https://raw.githubusercontent.com/TheresiaTriOktavia/PDT/main/supermarket_sales.csv"
df1 = pd.read_csv(url)
df1
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# Melihat informasi data (adakah data yang null dan tipe data pada tiap kolom)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
# Menghapus kolom non numerik
df_clean1 = df1.drop(["Invoice ID", "Branch", "City", "Customer type", "Gender", "Product line", "Date", "Time", "Payment"], axis=1)
df_clean1
# Out:
#      Unit price  Quantity   Tax 5%      Total    cogs  \
# 0         74.69         7  26.1415   548.9715  522.83
# 1         15.28         5   3.8200    80.2200   76.40
# 2         46.33         7  16.2155   340.5255  324.31
# 3         58.22         8  23.2880   489.0480  465.76
# 4         86.31         7  30.2085   634.3785  604.17
# ..          ...       ...      ...        ...     ...
# 995       40.35         1   2.0175    42.3675   40.35
# 996       97.38        10  48.6900  1022.4900  973.80
# 997       31.84         1   1.5920    33.4320   31.84
# 998       65.82         1   3.2910    69.1110   65.82
# 999       88.34         7  30.9190   649.2990  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ...

# %%
# Menghitung jumlah (sum) pada tiap kolom
# Mengatur sehingga hanya ada 2 angka di belakang koma
DataSum1 = df_clean1.sum().apply(lambda x: "{:.2f}".format(x))
DataSum1
# Out:
# Unit price                  55672.13
# Quantity                     5510.00
# Tax 5%                      15379.37
# Total                      322966.75
# cogs                       307587.38
# gross margin percentage      4761.90
# gross income                15379.37
# Rating                       6972.70
# dtype: object

# %%
# Menghitung rata-rata (mean) pada tiap kolom
# Mengatur sehingga hanya ada 2 angka di belakang koma
DataMean1 = df_clean1.mean().apply(lambda x: "{:.2f}".format(x))
DataMean1
# Out:
# Unit price                  55.67
# Quantity                     5.51
# Tax 5%                      15.38
# Total                      322.97
# cogs                       307.59
# gross margin percentage      4.76
# gross income                15.38
# Rating                       6.97
# dtype: object

# %%
# Menghitung nilai tengah (median) pada tiap kolom
# Mengatur sehingga hanya ada 2 angka di belakang koma
DataMedian1 = df_clean1.median().apply(lambda x: "{:.2f}".format(x))
DataMedian1
# Out:
# Unit price                  55.23
# Quantity                     5.00
# Tax 5%                      12.09
# Total                      253.85
# cogs                       241.76
# gross margin percentage      4.76
# gross income                12.09
# Rating                       7.00
# dtype: object

# %% [markdown]
# Data .txt

# %%
# Load Data .txt
url = "https://raw.githubusercontent.com/TheresiaTriOktavia/PDT/main/Life_Expectancy_Data.txt"
df2 = pd.read_csv(url)
df2
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0              263
# 1     Afghanistan  2014  Developing              59.9              271
# 2     Afghanistan  2013  Developing              59.9              268
# 3     Afghanistan  2012  Developing              59.5              272
# 4     Afghanistan  2011  Developing              59.2              275
# ...           ...   ...         ...               ...              ...
# 1644     Zimbabwe  2004  Developing              44.3              723
# 1645     Zimbabwe  2003  Developing              44.5              715
# 1646     Zimbabwe  2002  Developing              44.8               73
# 1647     Zimbabwe  2001  Developing              45.3              686
# 1648     Zimbabwe  2000  Developing              46.0              665
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# Melihat informasi data (adakah data yang null dan tipe data pada tiap kolom)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   int64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   int64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %%
# Menghapus kolom non numerik
df_clean2 = df2.drop(["Country", "Status"], axis=1)
df_clean2
# Out:
#       Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     2015              65.0              263             62     0.01
# 1     2014              59.9              271             64     0.01
# 2     2013              59.9              268             66     0.01
# 3     2012              59.5              272             69     0.01
# 4     2011              59.2              275             71     0.01
# ...    ...               ...              ...            ...      ...
# 1644  2004              44.3              723             27     4.36
# 1645  2003              44.5              715             26     4.06
# 1646  2002              44.8               73             25     4.43
# 1647  2001              45.3              686             25     1.72
# 1648  2000              46.0              665             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   \
# 0                  71.279624           65      1154   19.1
# ...

# %%
# Menghitung jumlah (sum) pada tiap kolom
# Mengatur sehingga hanya ada 2 angka di belakang koma
DataSum2 = df_clean2.sum().apply(lambda x: "{:.2f}".format(x))
DataSum2
# Out:
# Year                                   3310929.00
# Life expectancy                         114279.50
# Adult Mortality                         277387.00
# infant deaths                            53680.00
# Alcohol                                   7475.24
# percentage expenditure                 1152607.40
# Hepatitis B                             130630.00
# Measles                                3668191.00
#  BMI                                     62874.10
# under-five deaths                        72919.00
# Polio                                   137798.00
# Total expenditure                         9821.32
# Diphtheria                              138772.00
#  HIV/AIDS                                 3271.40
# GDP                                    9178386.58
# Population                         24163829091.76
#  thinness  1-19 years                     7998.70
#  thinness 5-9 years                       8092.90
# Income composition of resources           1041.43
# ...

# %%
# Menghitung rata-rata (mean) pada tiap kolom
# Mengatur sehingga hanya ada 2 angka di belakang koma
DataMean2 = df_clean2.mean().apply(lambda x: "{:.2f}".format(x))
DataMean2
# Out:
# Year                                   2007.84
# Life expectancy                          69.30
# Adult Mortality                         168.22
# infant deaths                            32.55
# Alcohol                                   4.53
# percentage expenditure                  698.97
# Hepatitis B                              79.22
# Measles                                2224.49
#  BMI                                     38.13
# under-five deaths                        44.22
# Polio                                    83.56
# Total expenditure                         5.96
# Diphtheria                               84.16
#  HIV/AIDS                                 1.98
# GDP                                    5566.03
# Population                         14653625.89
#  thinness  1-19 years                     4.85
#  thinness 5-9 years                       4.91
# Income composition of resources           0.63
# Schooling                                12.12
# dtype: object

# %%
# Menghitung nilai tengah (median) pada tiap kolom
# Mengatur sehingga hanya ada 2 angka di belakang koma
DataMedian2 = df_clean2.median().apply(lambda x: "{:.2f}".format(x))
DataMedian2
# Out:
# Year                                  2008.00
# Life expectancy                         71.70
# Adult Mortality                        148.00
# infant deaths                            3.00
# Alcohol                                  3.79
# percentage expenditure                 145.10
# Hepatitis B                             89.00
# Measles                                 15.00
#  BMI                                    43.70
# under-five deaths                        4.00
# Polio                                   93.00
# Total expenditure                        5.84
# Diphtheria                              92.00
#  HIV/AIDS                                0.10
# GDP                                   1592.57
# Population                         1419631.00
#  thinness  1-19 years                    3.00
#  thinness 5-9 years                      3.20
# Income composition of resources          0.67
# Schooling                               12.30
# dtype: object

# %% [markdown]
# # No 2

# %%
import matplotlib.pyplot as plt

def tampilkan_ilustrasi_kursi(data):
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.set_title("Ilustrasi Kursi Bioskop")

    kursi = []
    for i in range(1, 31):
        if data[i - 1] == "Terisi":
            kursi.append(1)  # 1 untuk kursi terisi
        else:
            kursi.append(0)  # 0 untuk kursi kosong

    ax.bar(range(1, 31), kursi, color=['blue' if x == 1 else 'gray' for x in kursi])
    ax.set_xlabel("Nomor Kursi")
    ax.set_ylabel("Status Kursi")
    ax.set_xticks(range(1, 31))
    ax.set_yticks([0, 1])
    ax.set_yticklabels(['Kosong', 'Terisi'])
    ax.grid(True)

    plt.show()

data_kursi = [
    "Terisi", "Terisi", "Terisi", "Kosong", "Kosong",
    "Kosong", "Kosong", "Kosong", "Kosong", "Terisi",
    "Kosong", "Kosong", "Terisi", "Kosong", "Kosong",
    "Terisi", "Terisi", "Terisi", "Terisi", "Terisi",
    "Terisi", "Kosong", "Terisi", "Terisi", "Terisi",
    "Terisi", "Kosong", "Kosong", "Kosong", "Kosong"
]

tampilkan_ilustrasi_kursi(data_kursi)

# %%
# Load Data
url = "https://raw.githubusercontent.com/TheresiaTriOktavia/PDT/main/Data_Kursi_Bioskop.csv"
df3 = pd.read_csv(url)
df3.set_index('No Kursi', inplace=True)
df3
# Out:
#          Keterangan
# No Kursi
# 1            Terisi
# 2            Terisi
# 3            Terisi
# 4            Kosong
# 5            Kosong
# 6            Kosong
# 7            Kosong
# 8            Kosong
# 9            Kosong
# 10           Terisi
# 11           Kosong
# 12           Kosong
# 13           Terisi
# 14           Kosong
# 15           Kosong
# 16           Terisi
# 17           Terisi
# 18           Terisi
# 19           Terisi
# 20           Terisi
# 21           Terisi
# 22           Kosong
# 23           Terisi
# 24           Terisi
# 25           Terisi
# 26           Terisi
# 27           Kosong
# 28           Kosong
# 29           Kosong
# 30           Kosong

# %%
def isi_kursi(df3, nomor_kursi):
    if df3.at[nomor_kursi, 'Keterangan'] == 'Kosong':
        df3.at[nomor_kursi, 'Keterangan'] = 'Terisi'
        print(f"Kursi nomor {nomor_kursi} telah berhasil diisi.\n")
    else:
        print(f"Maaf, kursi nomor {nomor_kursi} sudah terisi.\n")

def kosongkan_kursi(df3, nomor_kursi):
    if df3.at[nomor_kursi, 'Keterangan'] == 'Terisi':
        df3.at[nomor_kursi, 'Keterangan'] = 'Kosong'
        print(f"Kursi nomor {nomor_kursi} telah berhasil dikosongkan.\n")
    else:
        print(f"Maaf, kursi nomor {nomor_kursi} sudah kosong.\n")

def display_data(df3):
    print("Data Kursi Bioskop:\n")
    print(df3)


# Loop untuk mengisi atau mengosongkan kursi
while True:
    print("\nSilakan pilih menu:")
    print("1. Isi kursi")
    print("2. Kosongkan kursi")
    print("3. Tampilkan data kursi")
    print("4. Keluar")
    pilihan = input("Masukkan pilihan menu: ")

    if pilihan == '1':
        print("Silakan masukkan nomor kursi yang ingin Anda isi:")
        nomor_kursi = int(input())
        if nomor_kursi in df3.index:
            isi_kursi(df3, nomor_kursi)
        else:
            print("Nomor kursi tidak valid. Silakan coba lagi.")

    elif pilihan == '2':
        print("Silakan masukkan nomor kursi yang ingin Anda kosongkan:")
        nomor_kursi = int(input())
        if nomor_kursi in df3.index:
            kosongkan_kursi(df3, nomor_kursi)
        else:
            print("Nomor kursi tidak valid. Silakan coba lagi.")

    elif pilihan == '3':
        display_data(df3)

    elif pilihan == '4':
        print("Terima kasih. Program selesai.")
        break

    else:
        print("Pilihan tidak valid. Silakan pilih menu yang tersedia.")
# Out:
# Silakan pilih menu:
# 1. Isi kursi
# 2. Kosongkan kursi
# 3. Tampilkan data kursi
# 4. Keluar
# Masukkan pilihan menu: 3
# Data Kursi Bioskop:
#
#          Keterangan
# No Kursi
# 1            Terisi
# 2            Terisi
# 3            Terisi
# 4            Kosong
# 5            Kosong
# 6            Kosong
# 7            Kosong
# 8            Kosong
# 9            Kosong
# 10           Terisi
# 11           Kosong
# 12           Kosong
# 13           Terisi
# 14           Kosong
# 15           Kosong
# 16           Terisi
# 17           Terisi
# 18           Terisi
# 19           Terisi
# 20           Terisi
# 21           Terisi
# 22           Kosong
# 23           Terisi
# 24           Terisi
# 25           Terisi
# 26           Terisi
# 27           Kosong
# 28           Kosong
# 29           Kosong
# 30           Kosong
#
# Silakan pilih menu:
# 1. Isi kursi
# 2. Kosongkan kursi
# 3. Tampilkan data kursi
# 4. Keluar
# Masukkan pilihan menu: 1
# ...
